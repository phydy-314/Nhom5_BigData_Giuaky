# %%
# !pip install requests pymongo
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 23.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# TRUY XUẤT THÔNG TIN

# %%
import requests
from pymongo import MongoClient
import pandas as pd


uri = "mongodb+srv://linhtng22416c_db_user:JM9cMY1YwoxfKuJi@cluster0.zut6ycx.mongodb.net/?appName=Cluster0"
client = MongoClient(uri)

db = client['BigData_Midterm']  # Replace with your database name
collection = db['HealthCare_Insurance']  # Replace with your collection name

url = "https://rickandmortyapi.com/api/character"

def fetch_json_from_url(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for any errors
        return response.json()  # Return data as JSON
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Fetch data from the URL
data = fetch_json_from_url(url)

cursor = collection.find()
df = pd.DataFrame(list(cursor))

df.head()
# Out:
#                         _id  Gender       Age  Driving_License  Region_Code  \
# 0  697d9d4e310b59f99776e63d       0  0.333777                1           28
# 1  697d9d4e310b59f99776e63e       0  2.396751                1            3
# 2  697d9d4e310b59f99776e63f       0  0.527181                1           28
# 3  697d9d4e310b59f99776e640       0 -1.148985                1           11
# 4  697d9d4e310b59f99776e641       1 -0.633242                1           41
#
#    Previously_Insured  Vehicle_Age  Vehicle_Damage  Annual_Premium  \
# 0                   0            2               1         40454.0
# 1                   0            1               0         33536.0
# 2                   0            2               1         38294.0
# 3                   1            0               0         28619.0
# 4                   1            0               0         27496.0
#
#    Policy_Sales_Channel   Vintage  Response  Annual_Premium_Adjusted
# ...
